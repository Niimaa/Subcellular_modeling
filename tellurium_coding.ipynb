# %%
import tellurium as te
r = te.loada('''J1: S1 -> S2; K1*S1; K1 = 0.1; S1=10''')

# %%
m = r.simulate(0, 50, 100)

# %%
r.plot()

# %%
r.S1
# Out:
# 0.06737480503668831

# %%
r.S1 = 400
r.S1
# Out:
# 400.0

# %%
r.simulate (0, 50, 100)
# Out:
#         time,    [S1],    [S2]
#  [[        0,     400, 9.93263],
#   [ 0.505051,   380.3, 29.6331],
#   [   1.0101, 361.569, 48.3631],
#   [  1.51515, 343.762, 66.1706],
#   [   2.0202, 326.832, 83.1011],
#   [  2.52525, 310.735, 99.1979],
#   [   3.0303, 295.431, 114.502],
#   [  3.53535, 280.881, 129.052],
#   [   4.0404, 267.047, 142.886],
#   [  4.54545, 253.895, 156.038],
#   [  5.05051,  241.39, 168.543],
#   [  5.55556, 229.501, 180.431],
#   [  6.06061, 218.198, 191.735],
#   [  6.56566, 207.451, 202.481],
#   [  7.07071, 197.234, 212.699],
#   [  7.57576,  187.52, 222.413],
#   [  8.08081, 178.284, 231.648],
#   [  8.58586, 169.504, 240.429],
#   [  9.09091, 161.155, 248.777],
#   [  9.59596, 153.218, 256.714],
#   [   10.101, 145.672, 264.261],
#   [  10.6061, 138.497, 271.435],
#   [  11.1111, 131.676, 278.256],
#   [  11.6162, 125.191, 284.742],
#   [  12.1212, 119.025, 290.907],
#   [  12.6263, 113.163,  296.77],
#   [  13.1313,  107.59, 302.343],
# ...

# %%
r.plot()

# %%
r.getFloatingSpeciesIds()
# Out:
# ['S1', 'S2']

# %%
r.J1
# Out:
# 1.0

# %%
r.getRatesOfChange()
# Out:
# array([-0.26950424,  0.26950424])

# %%
r.setValue('K1', 0.5)

# %%
r.K1
# Out:
# 0.5

# %%
r.getGlobalParameterIds()
# Out:
# ['K1']

# %%
import teUtils

# %%
teUtils
# Out:
# <module 'teUtils' from 'c:\\users\\nafs080\\envs\\venv-py36\\lib\\site-packages\\teUtils\\__init__.py'>

# %%
example = teUtils.buildNetworks.getRandomNetwork(10, 12)
print(example)
# Out:
# var S0, S2, S4, S5, S6, S7, S8, S9
# ext S1, S3;
# S4 -> S0 + S2; k0*S4;
# S4 + S7 -> S9; k1*S4*S7;
# S6 -> S7; k2*S6;
# S5 + S5 -> S1; k3*S5*S5;
# S9 + S6 -> S4; k4*S9*S6;
# S0 -> S7; k5*S0;
# S3 -> S2; k6*S3;
# S4 -> S8 + S6; k7*S4;
# S4 -> S9; k8*S4;
# S5 -> S2; k9*S5;
# S8 + S2 -> S0; k10*S8*S2;
# S0 -> S5 + S9; k11*S0;
#
# k0 = 0.41934047734717883
# k1 = 0.20265236432746303
# k2 = 0.4860813499039721
# k3 = 0.17886048558607515
# k4 = 0.5359225563004159
# k5 = 0.2682197102790773
# k6 = 0.01131263897846313
# k7 = 0.5102637567626902
# k8 = 0.6882237246063049
# k9 = 0.3347537482438916
# k10 = 0.6170471434494513
# k11 = 0.8855226006450296
#
# S1 = 2
# S3 = 4
